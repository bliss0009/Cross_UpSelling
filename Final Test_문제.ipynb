# %% [markdown]
# # Data-Set : NationalNames.csv
# download : https://drive.google.com/file/d/0B9fcvsgEhJNsN0FUaGZudFYyTVU/view
#
# • Id: 행 구분자
#
# • Name: 유아 이름
#
# • Year: 출생연도
#
# • Gender: 성별
#
# • Count: 해당 (이름, 연도, 성별)의 출생횟수

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # 문제 1) us-baby-names/NationalNames.csv 파일을 읽어오고, 컬럼을 'id', 'name', 'year', 'sex', 'births' 로 바꾸기 (5점)
# -  dataframe으로 읽어올 것
# - 'names' 변수에 저장할 것

# %%
# 코드 작성

# %%
# 결과 출력

# %% [markdown]
# # 문제 2) 2012년 이후에 태어난  'Emma' 이름을 가진 남자 아이에 대한 총 출생횟수 구하기 (10점)

# %%
# 코드 작성

# %%
# 결과 출력
print('>> 2012년 이후에 태어난 Emma이름의 남자아이 총 출생횟수 : {}명'.format(결과변수))

# %% [markdown]
# # 문제 3) 각 연도별 남아와 여아의 총 출생횟수를 산출하고, 라인 플롯으로 나타내기 (20점)
# - index : 연도
# - 출력 컬럼 : 여아, 남아 <-- (신규 컬럼 추가 아님)
# - value :각 연도별 여아 총 출생횟수, 남아 총 출생횟수
# - 라인플롯의 제목 : 'The graph showing changes for births per year'

# %%
# 결과 포맷

sex  |   F    |   M
year |
-----------------
1880 |   42   |  51
1881 |   12   |  21
1882 |   12   |  11
        .
        .
        .

# %%
# 코드 작성

# %%
# 결과 출력

# %%
# 라인플롯 코드 작성

# %% [markdown]
# # 문제 4) 각 연도, 성별 그룹 내에서 각 이름의 출생횟수가 각 그룹에서 차지하는 비중(%)을 나타내는 열 추가하기 (20점)
#  - 추가 열이름 : **'pct'**로 생성
#  - **'pct'**열에 각 연도, 성별 그룹내의 각 이름에 대한 출생횟수 비중을 계산하여 추가
#
#  ex) 1880년에 태어난 여자아이 Mary란 이름의경우,
#      1880년에 태어난 여자아이들중에서 Mary란 이름이 차지하는 출생횟수 비중(%)이 얼마인지를 계산

# %%
# 결과 포맷

id  | name  | year | sex | births |  pct
--------------------------------------------------
1   | Mary  | 1880 |  F  | 1111   | 7.764334
2   | Anna  | 1880 |  F  | 4422   | 2.861759
3   | Emma  | 1880 |  F  | 4522   | 2.201268
199 | Cora  | 1881 |  M  | 3022   | 2.110001
255 | Tony  | 2002 |  M  | 1055   | 3.224548

# %%
# 코드 작성

# %%
# 결과 출력

# %% [markdown]
# # 5. 각 연도별, 성별에 따른 출생 빈도수가 가장 높은 이름 100개 추출하기 (15점)
#
# ex) dataframe에 각 연도의 남자 아이별, 여자 아이별로 가장 많이 태어난 이름 top 100개씩 추출하기
#    - 1880년에 가장 많이 태어난 여자이름 top 100
#    - 1880년에 가장 많이 태어난 남자이름 top 100
#    - 1881년에 가장 많이 태어난 여자이름 top 100
#    - 1881년에 가장 많이 태어난 남자이름 top 100
#                    .
#                    .
#                    .

# %%
# 코드 작성

# %%
# 결과 출력

# %% [markdown]
# # 6. 남자아이 / 여자아이 이름에 대한 시대별 추이를 분석하여 결과 도출하기 (30점)
#
#  -  전체연도에서 성별구분없이 가장 많이 출생한 이름 top10을 구해서
#     top10에 해당하는 이름에 대한 출생횟수 변화추이를 각각 이름별로
#     subplot 10행 1열의 라인플롯으로 나타낸다
#
#  - 그래프를 기반으로 결과 도출 (2000년을 기준으로 전에는 어떤 이름들이
#    유행했고, 이후에는 어떤 이름들이 유행했는지 확인)
#
#  - 하기 subplot과 같은 방식으로 그래프 생성하기

# %%
# 코드 작성

# %%
# 결과 출력

# %%
# subplot 코드 작성

# %%
# subplot 결과 포맷
from IPython.display import Image
Image(filename='asset/images/subplot1.png')
